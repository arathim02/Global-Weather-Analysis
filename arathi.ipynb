# %%
l=[]
for i in range(5):
    x=int(input("enter an integer"))
    l.append(x)

print(max(l))
print(min(l))
print(sum(l))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 l=[]
#       2 for i in range(5):
# ----> 3     x=int(input("enter an integer"))
#       4     l.append(x)
#       6 print(max(l))
#
# ValueError: invalid literal for int() with base 10: 'l'

# %%
d={"a":1, "b":2}
for x in d:
    print(x)
# Out:
# a
# b

# %%
import pandas as pd

# %%
df=pd.read_csv("GlobalWeatherRepository - GlobalWeatherRepository.csv")

# %%
a=[10,20,30,40,50]
i=1
whilei<len(a)

# %%
a=[1,2,3,4,5,6]
for x in a:
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
a=[1,3,4,4,4,5,6]
set(a)
# Out:
# {1, 3, 4, 5, 6}

# %%
a=[200,300,400]
print(a.index(300))
print(a.index(400))
print(a.index(200))
# Out:
# 1
# 2
# 0

# %%
a=[2,4,3,7,9]
a.clear()
print(a)
# Out:
# []

# %%
a=[1,2,3]
a.reverse()
print(a)
# Out:
# [3, 2, 1]

# %%
a=[6,3,9,1]
print(len(a))
print(max(a))
print(min(a))
print(sum(a))
print(sorted(a))
# Out:
# 4
# 9
# 1
# 19
# [1, 3, 6, 9]

# %%
import pandas as pd

# %%
df=pd.read_csv("GlobalWeatherRepository - GlobalWeatherRepository.csv")

# %%
df.head()
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# ...

# %%
df.tail()
# Out:
#           country location_name  latitude  longitude         timezone  \
# 135068  Venezuela       Caracas   10.5000   -66.9167  America/Caracas
# 135069    Vietnam         Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070      Yemen         Sanaa   15.3547    44.2067        Asia/Aden
# 135071     Zambia        Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072   Zimbabwe        Harare  -17.8178    31.0447    Africa/Harare
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 135068          1775975400  2026-04-12 02:30                 19.1
# 135069          1775975400  2026-04-12 13:30                 34.2
# 135070          1775975400  2026-04-12 09:30                 19.3
# 135071          1775975400  2026-04-12 08:30                 18.5
# 135072          1775975400  2026-04-12 08:30                 17.4
#
#         temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 135068                    66.3  Partly Cloudy  ...              16.35
# ...

# %%
df.sample(8)
# Out:
#            country location_name  latitude  longitude          timezone  \
# 92286     Mongolia   Ulaanbaatar   47.9167   106.9167  Asia/Ulaanbaatar
# 68391      Tunisia         Tunis   36.8028    10.1797      Africa/Tunis
# 81592      Romania     Bucharest   44.4333    26.1000  Europe/Bucharest
# 49220    Mauritius    Port Louis  -20.1619    57.4989  Indian/Mauritius
# 115801     Comoros        Moroni  -11.7042    43.2403     Indian/Comoro
# 66185   Mozambique        Maputo  -25.9653    32.5892     Africa/Maputo
# 31459     Botswana      Gaborone  -24.6464    25.9119   Africa/Gaborone
# 6226    Uzbekistan      Tashkent   41.3200    69.2500     Asia/Tashkent
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 92286           1756886400  2025-09-03 16:00                 21.2
# 68391           1746262800  2025-05-03 10:00                 25.0
# 81592           1752137100  2025-07-10 11:45                 24.3
# ...

# %%
df.shape
# Out:
# (135073, 41)

# %%
df.columns
# Out:
# Index(['country', 'location_name', 'latitude', 'longitude', 'timezone',
#        'last_updated_epoch', 'last_updated', 'temperature_celsius',
#        'temperature_fahrenheit', 'condition_text', 'wind_mph', 'wind_kph',
#        'wind_degree', 'wind_direction', 'pressure_mb', 'pressure_in',
#        'precip_mm', 'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df.dtypes
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# ...

# %%
  df["country"]
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3             Andorra
# 4              Angola
#              ...
# 135068      Venezuela
# 135069        Vietnam
# 135070          Yemen
# 135071         Zambia
# 135072       Zimbabwe
# Name: country, Length: 135073, dtype: object

# %%
df.iloc[5:10]
# Out:
#                country location_name  latitude  longitude  \
# 5  Antigua and Barbuda  Saint John's     17.12     -61.85
# 6            Argentina  Buenos Aires    -34.59     -58.67
# 7              Armenia       Yerevan     40.18      44.51
# 8            Australia      Canberra    -35.28     149.22
# 9              Austria        Vienna     48.20      16.37
#
#                          timezone  last_updated_epoch      last_updated  \
# 5                 America/Antigua          1715849100  2024-05-16 04:45
# 6  America/Argentina/Buenos_Aires          1715849100  2024-05-16 05:45
# 7                    Asia/Yerevan          1715849100  2024-05-16 12:45
# 8                Australia/Sydney          1715849100  2024-05-16 18:45
# 9                   Europe/Vienna          1715849100  2024-05-16 10:45
#
#    temperature_celsius  temperature_fahrenheit condition_text  ...  \
# 5                 26.0                    78.8  Partly cloudy  ...
# ...

# %%
df[df["latitude"]>50]
# Out:
#                country location_name  latitude  longitude           timezone  \
# 15             Belarus         Minsk   53.9000    27.5700       Europe/Minsk
# 16             Belgium      Brussels   50.8300     4.3300    Europe/Brussels
# 44      Czech Republic        Prague   50.0800    14.4700      Europe/Prague
# 46             Denmark    Copenhagen   55.6700    12.5800  Europe/Copenhagen
# 55             Estonia       Tallinn   59.4300    24.7300     Europe/Tallinn
# ...                ...           ...       ...        ...                ...
# 135017          Poland        Warsaw   52.2500    21.0000      Europe/Warsaw
# 135021          Russia        Moscow   55.7522    37.6156      Europe/Moscow
# 135046          Sweden     Stockholm   59.3333    18.0500   Europe/Stockholm
# 135061         Ukraine          Kyiv   50.4333    30.5167        Europe/Kyiv
# 135063  United Kingdom        London   51.5171    -0.1062      Europe/London
#
# ...

# %%
df["latitude"]>50
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 135068    False
# 135069    False
# 135070    False
# 135071    False
# 135072    False
# Name: latitude, Length: 135073, dtype: bool

# %%
len(df[df["latitude"]>50])
# Out:
# 13835

# %%
df[(df["latitude"]>50) & (df["latitude"]<100)]
# Out:
#                country location_name  latitude  longitude           timezone  \
# 15             Belarus         Minsk   53.9000    27.5700       Europe/Minsk
# 16             Belgium      Brussels   50.8300     4.3300    Europe/Brussels
# 44      Czech Republic        Prague   50.0800    14.4700      Europe/Prague
# 46             Denmark    Copenhagen   55.6700    12.5800  Europe/Copenhagen
# 55             Estonia       Tallinn   59.4300    24.7300     Europe/Tallinn
# ...                ...           ...       ...        ...                ...
# 135017          Poland        Warsaw   52.2500    21.0000      Europe/Warsaw
# 135021          Russia        Moscow   55.7522    37.6156      Europe/Moscow
# 135046          Sweden     Stockholm   59.3333    18.0500   Europe/Stockholm
# 135061         Ukraine          Kyiv   50.4333    30.5167        Europe/Kyiv
# 135063  United Kingdom        London   51.5171    -0.1062      Europe/London
#
# ...

# %%
df[(df["latitude"]>50) | (df["latitude"]<100)]
# Out:
#             country     location_name  latitude  longitude         timezone  \
# 0       Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1           Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2           Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3           Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...             ...               ...       ...        ...              ...
# 135068    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 135069      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 135070        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 135071       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 135072     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
# ...

# %%
df[""]

# %%
df[(df)["latitude"]>50 * (df["longitude"]<100)]
# Out:
#                   country        location_name  latitude  longitude  \
# 15                Belarus                Minsk   53.9000    27.5700
# 16                Belgium             Brussels   50.8300     4.3300
# 24      Brunei Darussalam  Bandar Seri Begawan    4.8800   114.9300
# 30               Cambodia           Phnom Penh   11.5500   104.9200
# 36                  China              Beijing   39.9300   116.3900
# ...                   ...                  ...       ...        ...
# 135046             Sweden            Stockholm   59.3333    18.0500
# 135051           Thailand              Bangkok   13.7500   100.5167
# 135061            Ukraine                 Kyiv   50.4333    30.5167
# 135063     United Kingdom               London   51.5171    -0.1062
# 135069            Vietnam                Hanoi   21.0333   105.8500
#
#                 timezone  last_updated_epoch      last_updated  \
# 15          Europe/Minsk          1715849100  2024-05-16 11:45
# ...

# %%
df["timezone"].dtype
# Out:
# dtype('O')

# %%
df["test"]=df["timezone"]

# %%
df["test2"]=df["timezone"].str.split("/")

# %%
["latituddfe"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ["latituddfe"].value_counts()
#
# AttributeError: 'list' object has no attribute 'value_counts'

# %%
import pandas as pd

# %%
df=pd.read_csv("GlobalWeatherRepository - GlobalWeatherRepository.csv")

# %%
df["latitude"].value_counts()
# Out:
# latitude
#  41.90    833
#  40.40    832
#  12.15    830
#  5.55     695
#  3.75     695
#          ...
#  39.53      1
#  4.60       1
#  4.05       1
# -4.05       1
#  59.89      1
# Name: count, Length: 397, dtype: int64

# %%
df["latitude"].mean()
# Out:
# np.float64(19.208948125087915)

# %%
df["latitude"].max()
# Out:
# 64.15

# %%
df["latitude"].min()
# Out:
# -41.3

# %%
df[df["country"]== "China"]
# Out:
#        country location_name  latitude  longitude       timezone  \
# 36       China       Beijing   39.9300   116.3900  Asia/Shanghai
# 231      China       Beijing   39.9300   116.3900  Asia/Shanghai
# 426      China       Beijing   39.9300   116.3900  Asia/Shanghai
# 618      China       Beijing   39.9300   116.3900  Asia/Shanghai
# 812      China       Beijing   39.9300   116.3900  Asia/Shanghai
# ...        ...           ...       ...        ...            ...
# 134134   China       Beijing   39.9289   116.3883  Asia/Shanghai
# 134329   China       Beijing   39.9289   116.3883  Asia/Shanghai
# 134524   China       Beijing   39.9289   116.3883  Asia/Shanghai
# 134719   China       Beijing   39.9289   116.3883  Asia/Shanghai
# 134914   China       Beijing   39.9289   116.3883  Asia/Shanghai
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# 36              1715849100  2024-05-16 16:45                 29.0
# ...

# %%
df.isnull().sum()
# Out:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# ...

# %%
df.isnull()
# Out:
#         country  location_name  latitude  longitude  timezone  \
# 0         False          False     False      False     False
# 1         False          False     False      False     False
# 2         False          False     False      False     False
# 3         False          False     False      False     False
# 4         False          False     False      False     False
# ...         ...            ...       ...        ...       ...
# 135068    False          False     False      False     False
# 135069    False          False     False      False     False
# 135070    False          False     False      False     False
# 135071    False          False     False      False     False
# 135072    False          False     False      False     False
#
#         last_updated_epoch  last_updated  temperature_celsius  \
# 0                    False         False                False
# 1                    False         False                False
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sort_values(by="latitude")
# Out:
#             country location_name  latitude  longitude            timezone  \
# 101262  New Zealand    Wellington    -41.30   174.7833    Pacific/Auckland
# 12891   New Zealand    Wellington    -41.30   174.7800    Pacific/Auckland
# 24760   New Zealand    Wellington    -41.30   174.7800    Pacific/Auckland
# 94439   New Zealand    Wellington    -41.30   174.7833    Pacific/Auckland
# 115496  New Zealand    Wellington    -41.30   174.7833    Pacific/Auckland
# ...             ...           ...       ...        ...                 ...
# 128909      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 91663       Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 131249      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 104334      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
# 126942      Iceland     Reykjavik     64.15   -21.9500  Atlantic/Reykjavik
#
#         last_updated_epoch      last_updated  temperature_celsius  \
# ...

# %%
df=df.drop_duplicates()

# %%
df=df.dropna(subset=["latitude"])

# %%
df["latitude"] = df["latitude"].fillna(0)

# %%
df["latitude"] = df["latitude"].fillna(df["latitude"].mean())

# %%
df["latitude"] = df["latitude"].ffill()
df["latitude"] = df["latitude"].bfill()

# %%
df["location_name"] = df["location_name"].str.replace("+","")

# %%
df["latitude"] = df["latitude"].astype(int)

# %%
df["country"].str.lower()
# Out:
# 0         afghanistan
# 1             albania
# 2             algeria
# 3             andorra
# 4              angola
#              ...
# 135068      venezuela
# 135069        vietnam
# 135070          yemen
# 135071         zambia
# 135072       zimbabwe
# Name: country, Length: 135073, dtype: object
